# %% [markdown]
# <h1><center> Tópicos Avançados em Python para Análise de Dados </center></h1>

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1qCH-jlzKK1aFaTBpiTHN4qxTFrCVs720)

# %% [markdown]
# <center>
# <h5>
# O objetivo desse material é mostrar a você como aplicar diversos métodos das duas bibliotecas mais famosas para Ciência de Dados: Pandas e Seaborn. Ao longo do curso além de conhecermos como essas ferramentas funcionam vamos praticar a análise em dados reais e transformar os dados que temos em informações.
# Vamos nessa!
# <h5>
# <center>

# %% [markdown]
# ## Módulo 2:

# %% [markdown]
# ### Lição 1: Objetivos do módulo

# %% [markdown]
# ### Lição 2: Apresentação e entendimento dos dados

# %% [markdown]
# ### Lição 3: Leitura de arquivos com o Pandas

# %% [markdown]
# Uma das grandes utilidades do **Pandas** é a facilidade para trabalhar com diferentes arquivos de dados.
#
# A leitura de dados, geralmente, é o primeiro passo em qualquer projeto de um cientista de dados.
#
# É muito comum lidarmos com o formato CSV (*Comma Separeted Values*).
#
# Assim, vamos usar o método **.read_csv('name_of_file.csv')** para facilitar a leitura do nosso arquivo de dados.

# %%
import pandas as pd

# %%
dados = pd.read_csv ('listings.csv')

# %% [markdown]
# O código acima mostra que a nossa base *listings.csv* vai ser armazenada na variável *dados* no formato de um DataFrame.
#
# Através do **.read_csv**, conseguimos importar a base de dados que usaremos ao longo do curso. Observe que apenas passamos o nome (ou localização) do arquivo como parâmetro para a função, porém ela apresenta diversos parâmetros interessantes para lermos nossos dados:
#
# * *sep* -> Determina qual separador será usado para delimitar os campos da base. Default = ','
# * *usecols* -> Determina quais colunas específicas queremos utilizar
# * *nrows* -> Ao invés de ler todas as linhas da base, a função lerá apenas a quantidade determinada
# * header -> Indica qual linha será usada como cabeçalho da base de dados
#
# Para ver os demais parâmetros veja a [documentação](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
#Célula para mostrar os diferentes tipos de leitura que podemos ter

# %% [markdown]
# Podemos visualizar um DataFrame da seguinte forma:

# %%
dados
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1         20168       Studio with private bathroom in the centre 1      59484
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan      56142
# 3         27886  Romantic, stylish B&B houseboat in canal district      97647
# 4         28871                            Comfortable double room     124245
# ...         ...                                                ...        ...
# 18777  45761390              Charming 1Room Apartment in Amsterdam  310835509
# 18778  45763935         clean and light apartment nearby the water     961670
# 18779  45776325   A beautiful spacious room on a central location.   48168060
# 18780  45777642                                Studio in Amsterdam   75268907
# 18781  45783000             Spacious and cozy apartment in De Pijp  371160113
#
#         host_name  neighbourhood_group  \
# 0          Daniel                  NaN
# 1       Alexander                  NaN
# 2            Joan                  NaN
# 3            Flip                  NaN
# 4           Edwin                  NaN
# ...           ...                  ...
# 18777  TravelNest                  NaN
# 18778        Lisa                  NaN
# 18779         Tim                  NaN
# 18780        Emma                  NaN
# 18781     Nadezda                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 0      Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                                Centrum-Oost  52.36424    4.89396
# 2                                Centrum-West  52.37297    4.88339
# 3                                Centrum-West  52.38761    4.89188
# 4                                Centrum-West  52.36719    4.89092
# ...                                       ...       ...        ...
# 18777                           Bos en Lommer  52.37642    4.84941
# 18778                              Westerpark  52.39042    4.88204
# 18779                 De Pijp - Rivierenbuurt  52.34306    4.89995
# 18780                         Watergraafsmeer  52.34885    4.91878
# 18781                 De Pijp - Rivierenbuurt  52.35380    4.89740
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     59               3                278  2020-02-14
# 1         Private room    236               1                340  2020-04-09
# 2      Entire home/apt    125              14                  5  2020-02-09
# 3         Private room    138               2                219  2020-07-25
# 4         Private room     75               2                336  2020-09-20
# ...                ...    ...             ...                ...         ...
# 18777  Entire home/apt    137               1                  0         NaN
# 18778  Entire home/apt    120               5                  0         NaN
# 18779     Private room     20               1                  0         NaN
# 18780  Entire home/apt     33              10                  0         NaN
# 18781  Entire home/apt    105               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   1.98                               1                 0
# 1                   2.63                               2                 0
# 2                   0.15                               1                58
# 3                   2.05                               1               158
# 4                   2.72                               2               340
# ...                  ...                             ...               ...
# 18777                NaN                               1               339
# 18778                NaN                               2                51
# 18779                NaN                               2                 0
# 18780                NaN                               1                15
# 18781                NaN                               1               253
#
# [18782 rows x 16 columns]

# %% [markdown]
# Os *DataFrames* possuem dois métodos interessantes para visualização dos dados: o **.head()** e o **.tail()**.
#
# O primeiro mostra apenas uma determinada quantidade de linhas iniciais (head = cabeça = início) dos nossos dados, enquanto o segundo mostra apenas uma determinada quantidade de linhas finais (tail = rabo = final) dos nossos dados.

# %%
dados.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  25428    Lovely apt in City Centre (w.lift) near Jordaan    56142
# 3  27886  Romantic, stylish B&B houseboat in canal district    97647
# 4  28871                            Comfortable double room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Joan                  NaN                            Centrum-West
# 3       Flip                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-West
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  52.36575    4.94142     Private room     59               3
# 1  52.36424    4.89396     Private room    236               1
# 2  52.37297    4.88339  Entire home/apt    125              14
# 3  52.38761    4.89188     Private room    138               2
# 4  52.36719    4.89092     Private room     75               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                278  2020-02-14               1.98
# 1                340  2020-04-09               2.63
# 2                  5  2020-02-09               0.15
# 3                219  2020-07-25               2.05
# 4                336  2020-09-20               2.72
#
#    calculated_host_listings_count  availability_365
# 0                               1                 0
# 1                               2                 0
# 2                               1                58
# 3                               1               158
# 4                               2               340

# %%
dados.tail()
# Out:
#              id                                              name    host_id  \
# 18777  45761390             Charming 1Room Apartment in Amsterdam  310835509
# 18778  45763935        clean and light apartment nearby the water     961670
# 18779  45776325  A beautiful spacious room on a central location.   48168060
# 18780  45777642                               Studio in Amsterdam   75268907
# 18781  45783000            Spacious and cozy apartment in De Pijp  371160113
#
#         host_name  neighbourhood_group            neighbourhood  latitude  \
# 18777  TravelNest                  NaN            Bos en Lommer  52.37642
# 18778        Lisa                  NaN               Westerpark  52.39042
# 18779         Tim                  NaN  De Pijp - Rivierenbuurt  52.34306
# 18780        Emma                  NaN          Watergraafsmeer  52.34885
# 18781     Nadezda                  NaN  De Pijp - Rivierenbuurt  52.35380
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 18777    4.84941  Entire home/apt    137               1                  0
# 18778    4.88204  Entire home/apt    120               5                  0
# 18779    4.89995     Private room     20               1                  0
# 18780    4.91878  Entire home/apt     33              10                  0
# 18781    4.89740  Entire home/apt    105               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 18777         NaN                NaN                               1
# 18778         NaN                NaN                               2
# 18779         NaN                NaN                               2
# 18780         NaN                NaN                               1
# 18781         NaN                NaN                               1
#
#        availability_365
# 18777               339
# 18778                51
# 18779                 0
# 18780                15
# 18781               253

# %% [markdown]
# Podemos perceber que temos diversas linhas e diversas colunas:
# * Cada coluna corresponde a uma informação do nosso DataFrame, como nome do hospedeiro, qual a vizinhança que o Airbnb se encontra, etc.
# * Cada linha representa um Airbnb diferente, uma instância.
#
# Os números em negrito à esquerda são referentes aos índices e os nomes em negrito são referentes aos nomes das colunas. Assim como pegamos os índices ao lidarmos com *Series*, podemos fazer a mesma coisa com DataFrames

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=18782, step=1)

# %% [markdown]
# Além dos índices, podemos também pegar os valores e as colunas de um DataFrame

# %%
dados.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
dados.values
# Out:
# array([[2818, 'Quiet Garden View Room & Super Fast WiFi', 3159, ...,
#         1.98, 1, 0],
#        [20168, 'Studio with private bathroom in the centre 1', 59484,
#         ..., 2.63, 2, 0],
#        [25428, 'Lovely apt in City Centre (w.lift) near Jordaan', 56142,
#         ..., 0.15, 1, 58],
#        ...,
#        [45776325, 'A beautiful spacious room on a central location.',
#         48168060, ..., nan, 2, 0],
#        [45777642, 'Studio in Amsterdam', 75268907, ..., nan, 1, 15],
#        [45783000, 'Spacious and cozy apartment in De Pijp', 371160113,
#         ..., nan, 1, 253]], dtype=object)

# %% [markdown]
# Observe que o atributo *values* transformou o DataFrame em um *Numpy Array*

# %% [markdown]
# ### Lição 4: Tipos de dados

# %% [markdown]
# Para identificar os tipos de dados que temos em nosso *DataFrame* usamos o atributo **.dtypes**

# %%
dados.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# Veja que ele retorna o tipo de dado de cada uma das colunas do *DataFrame*, em que temos dados numéricos (int e float) e dados do tipo object. É importante ressaltar que se usarmos a função nativa *type()* o resultado será diferente.

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A função *type()* mostra qual o tipo da variável *dados* e não das colunas dentro dela.

# %% [markdown]
# O **Pandas** nos permite selecionar os tipos de dados das colunas que queremos trabalhar através do método **.select_dtypes()**. Isso é útil, por exemplo, quando queremos trabalhar apenas com colunas numéricas ou apenas colunas de texto

# %%
colunas_int = dados.select_dtypes(include='int64')
colunas_int.dtypes
# Out:
# id                                int64
# host_id                           int64
# price                             int64
# minimum_nights                    int64
# number_of_reviews                 int64
# calculated_host_listings_count    int64
# availability_365                  int64
# dtype: object

# %%
colunas_numericas = dados.select_dtypes(include=['int64','float64'])
colunas_numericas.dtypes
# Out:
# id                                  int64
# host_id                             int64
# neighbourhood_group               float64
# latitude                          float64
# longitude                         float64
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
colunas_object = dados.select_dtypes(exclude=['int64','float64'])
colunas_object.dtypes
# Out:
# name             object
# host_name        object
# neighbourhood    object
# room_type        object
# last_review      object
# dtype: object

# %% [markdown]
# ### Lição 5: Selecionando colunas

# %% [markdown]
# O *DataFrame* permite acessarmos apenas os dados de uma coluna específica.

# %%
dados['host_name']
# Out:
# 0            Daniel
# 1         Alexander
# 2              Joan
# 3              Flip
# 4             Edwin
#             ...
# 18777    TravelNest
# 18778          Lisa
# 18779           Tim
# 18780          Emma
# 18781       Nadezda
# Name: host_name, Length: 18782, dtype: object

# %% [markdown]
# Mas e se quiséssemos acessar várias colunas de uma vez?

# %%
dados[['id','host_name']]
# Out:
#              id   host_name
# 0          2818      Daniel
# 1         20168   Alexander
# 2         25428        Joan
# 3         27886        Flip
# 4         28871       Edwin
# ...         ...         ...
# 18777  45761390  TravelNest
# 18778  45763935        Lisa
# 18779  45776325         Tim
# 18780  45777642        Emma
# 18781  45783000     Nadezda
#
# [18782 rows x 2 columns]

# %% [markdown]
# Observe que ao fazermos isso, temos uma *Series* ou um *DataFrame* com todas as informações da coluna selecionada.
#
# Esse tipo de acesso lembra o acesso dos **dicionários**, no qual queríamos todos os valores relacionados a uma ou mais chaves.

# %% [markdown]
# Porém, os DataFrames também oferecem uma diferente forma de acesso:

# %%
dados.id
# Out:
# 0            2818
# 1           20168
# 2           25428
# 3           27886
# 4           28871
#            ...
# 18777    45761390
# 18778    45763935
# 18779    45776325
# 18780    45777642
# 18781    45783000
# Name: id, Length: 18782, dtype: int64

# %% [markdown]
# Dessa forma, acessamos as colunas como se elas fossem atributos do nosso *DataFrame*.
#
# Porém, é preciso termos atenção ao usar esse tipo de acesso, pois ele **não funcionará com colunas que apresentam espaços em seus nomes**.

# %% [markdown]
# ### Lição 6: Adição e exclusão de novas variáveis

# %% [markdown]
# Os *DataFrames* e as *Series* são estruturas mutáveis, ou seja, conseguimos adicionar e retirar elementos. Nesse caso, é possível retirar e adicionar linhas e colunas.
#
# Podemos adicionar colunas dos DataFrames com base em outras.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1Qe1D7MeNztguBz0wRRd6U6ueYr2ZFg7f)

# %% [markdown]
# Como a nossa base de dados é sobre Airbnbs em Amsterdam, o preço dos hotéis é dado em Euros. Apesar do Euro ser uma moeda conhecida, seria mais interessante que esse preço estivesse em dólar, já que essa é a moeda base para a economia mundial.
#
# Sabemos que 1 euro = 1,18 dólar. Assim, podemos criar a coluna *price_dolar* da seguinte forma:

# %%
price_dolar = dados.price * 1.18

# %%
dados['price_dolar'] = price_dolar

# %%
dados
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1         20168       Studio with private bathroom in the centre 1      59484
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan      56142
# 3         27886  Romantic, stylish B&B houseboat in canal district      97647
# 4         28871                            Comfortable double room     124245
# ...         ...                                                ...        ...
# 18777  45761390              Charming 1Room Apartment in Amsterdam  310835509
# 18778  45763935         clean and light apartment nearby the water     961670
# 18779  45776325   A beautiful spacious room on a central location.   48168060
# 18780  45777642                                Studio in Amsterdam   75268907
# 18781  45783000             Spacious and cozy apartment in De Pijp  371160113
#
#         host_name  neighbourhood_group  \
# 0          Daniel                  NaN
# 1       Alexander                  NaN
# 2            Joan                  NaN
# 3            Flip                  NaN
# 4           Edwin                  NaN
# ...           ...                  ...
# 18777  TravelNest                  NaN
# 18778        Lisa                  NaN
# 18779         Tim                  NaN
# 18780        Emma                  NaN
# 18781     Nadezda                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 0      Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                                Centrum-Oost  52.36424    4.89396
# 2                                Centrum-West  52.37297    4.88339
# 3                                Centrum-West  52.38761    4.89188
# 4                                Centrum-West  52.36719    4.89092
# ...                                       ...       ...        ...
# 18777                           Bos en Lommer  52.37642    4.84941
# 18778                              Westerpark  52.39042    4.88204
# 18779                 De Pijp - Rivierenbuurt  52.34306    4.89995
# 18780                         Watergraafsmeer  52.34885    4.91878
# 18781                 De Pijp - Rivierenbuurt  52.35380    4.89740
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     59               3                278  2020-02-14
# 1         Private room    236               1                340  2020-04-09
# 2      Entire home/apt    125              14                  5  2020-02-09
# 3         Private room    138               2                219  2020-07-25
# 4         Private room     75               2                336  2020-09-20
# ...                ...    ...             ...                ...         ...
# 18777  Entire home/apt    137               1                  0         NaN
# 18778  Entire home/apt    120               5                  0         NaN
# 18779     Private room     20               1                  0         NaN
# 18780  Entire home/apt     33              10                  0         NaN
# 18781  Entire home/apt    105               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   1.98                               1                 0
# 1                   2.63                               2                 0
# 2                   0.15                               1                58
# 3                   2.05                               1               158
# 4                   2.72                               2               340
# ...                  ...                             ...               ...
# 18777                NaN                               1               339
# 18778                NaN                               2                51
# 18779                NaN                               2                 0
# 18780                NaN                               1                15
# 18781                NaN                               1               253
#
#        price_dolar
# 0            69.62
# 1           278.48
# 2           147.50
# 3           162.84
# 4            88.50
# ...            ...
# 18777       161.66
# 18778       141.60
# 18779        23.60
# 18780        38.94
# 18781       123.90
#
# [18782 rows x 17 columns]

# %% [markdown]
# Para removermos uma coluna no **Pandas** usamos o método **.drop()**. Esse método remove linhas e/ou colunas especificadas. É importante lembrar que ele retorna o *DataFrame* modificado, mas não muda nossos dados direto na memória. Por isso, se quisermos que nossos dados não possuam certa linha ou coluna devemos atribuir o novo *DataFrame* a variável dos dados.

# %%
dados.drop(columns='price_dolar')
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1         20168       Studio with private bathroom in the centre 1      59484
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan      56142
# 3         27886  Romantic, stylish B&B houseboat in canal district      97647
# 4         28871                            Comfortable double room     124245
# ...         ...                                                ...        ...
# 18777  45761390              Charming 1Room Apartment in Amsterdam  310835509
# 18778  45763935         clean and light apartment nearby the water     961670
# 18779  45776325   A beautiful spacious room on a central location.   48168060
# 18780  45777642                                Studio in Amsterdam   75268907
# 18781  45783000             Spacious and cozy apartment in De Pijp  371160113
#
#         host_name  neighbourhood_group  \
# 0          Daniel                  NaN
# 1       Alexander                  NaN
# 2            Joan                  NaN
# 3            Flip                  NaN
# 4           Edwin                  NaN
# ...           ...                  ...
# 18777  TravelNest                  NaN
# 18778        Lisa                  NaN
# 18779         Tim                  NaN
# 18780        Emma                  NaN
# 18781     Nadezda                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 0      Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                                Centrum-Oost  52.36424    4.89396
# 2                                Centrum-West  52.37297    4.88339
# 3                                Centrum-West  52.38761    4.89188
# 4                                Centrum-West  52.36719    4.89092
# ...                                       ...       ...        ...
# 18777                           Bos en Lommer  52.37642    4.84941
# 18778                              Westerpark  52.39042    4.88204
# 18779                 De Pijp - Rivierenbuurt  52.34306    4.89995
# 18780                         Watergraafsmeer  52.34885    4.91878
# 18781                 De Pijp - Rivierenbuurt  52.35380    4.89740
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     59               3                278  2020-02-14
# 1         Private room    236               1                340  2020-04-09
# 2      Entire home/apt    125              14                  5  2020-02-09
# 3         Private room    138               2                219  2020-07-25
# 4         Private room     75               2                336  2020-09-20
# ...                ...    ...             ...                ...         ...
# 18777  Entire home/apt    137               1                  0         NaN
# 18778  Entire home/apt    120               5                  0         NaN
# 18779     Private room     20               1                  0         NaN
# 18780  Entire home/apt     33              10                  0         NaN
# 18781  Entire home/apt    105               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   1.98                               1                 0
# 1                   2.63                               2                 0
# 2                   0.15                               1                58
# 3                   2.05                               1               158
# 4                   2.72                               2               340
# ...                  ...                             ...               ...
# 18777                NaN                               1               339
# 18778                NaN                               2                51
# 18779                NaN                               2                 0
# 18780                NaN                               1                15
# 18781                NaN                               1               253
#
# [18782 rows x 16 columns]

# %%
dados = dados.drop(columns='price_dolar')
dados.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  25428    Lovely apt in City Centre (w.lift) near Jordaan    56142
# 3  27886  Romantic, stylish B&B houseboat in canal district    97647
# 4  28871                            Comfortable double room   124245
#
#    host_name  neighbourhood_group                           neighbourhood  \
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Joan                  NaN                            Centrum-West
# 3       Flip                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-West
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  52.36575    4.94142     Private room     59               3
# 1  52.36424    4.89396     Private room    236               1
# 2  52.37297    4.88339  Entire home/apt    125              14
# 3  52.38761    4.89188     Private room    138               2
# 4  52.36719    4.89092     Private room     75               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                278  2020-02-14               1.98
# 1                340  2020-04-09               2.63
# 2                  5  2020-02-09               0.15
# 3                219  2020-07-25               2.05
# 4                336  2020-09-20               2.72
#
#    calculated_host_listings_count  availability_365
# 0                               1                 0
# 1                               2                 0
# 2                               1                58
# 3                               1               158
# 4                               2               340

# %% [markdown]
# ### Lição 7: Indexação de dados

# %% [markdown]
# Ao contrário dos arrays de duas dimensões, não conseguimos acessar dados na forma *dataframe[linha][coluna]*.

# %%
dados[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-795f4a44a5af> in <module>
# ----> 1 dados[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %% [markdown]
# Dessa forma, os *DataFrames* possuem dois principais métodos para acessarmos as linhas dos nossos dados: **.loc()** e **.iloc()**.

# %% [markdown]
# #### iLoc

# %% [markdown]
# O método **.iloc()** é baseado em localização inteira (de 0 até tamanho - 1) e ajuda você a selecionar pela posição. Digamos que queremos saber as informações do Airbnb da posição 10 podemos fazer o seguinte:

# %%
dados.iloc[10]
# Out:
# id                                                         46386
# name                              Cozy loft in central Amsterdam
# host_id                                                   207342
# host_name                                                  Joost
# neighbourhood_group                                          NaN
# neighbourhood                            De Pijp - Rivierenbuurt
# latitude                                                 52.3525
# longitude                                                4.90825
# room_type                                        Entire home/apt
# price                                                        150
# minimum_nights                                                 3
# number_of_reviews                                              3
# last_review                                           2018-01-03
# reviews_per_month                                           0.02
# calculated_host_listings_count                                 1
# availability_365                                               0
# Name: 10, dtype: object

# %% [markdown]
# Além de poder receber como entrada um inteiro, o **.iloc()** pode receber como entrada:
#
# * Uma lista de inteiros. Ex: [1, 2, 5, 9, 10]
# * Uma fatia (slice). Ex: [1:7]
# * Um array booleano ou expressões booleanas. Ex: [True, False, False, True]. É importante ressaltar que esse array deve ser do tamanho do DataFrame
# * Uma função que pode ser chamada com um argumento e que retorna uma saída válida para indexação. Ex: funções lambda

# %%
dados.iloc[[1,2,5,9,10]]
# Out:
#        id                                             name  host_id  \
# 1   20168     Studio with private bathroom in the centre 1    59484
# 2   25428  Lovely apt in City Centre (w.lift) near Jordaan    56142
# 5   29051                          Comfortable single room   124245
# 9   44129                    Luxury design with canal view   187728
# 10  46386                   Cozy loft in central Amsterdam   207342
#
#     host_name  neighbourhood_group            neighbourhood  latitude  \
# 1   Alexander                  NaN             Centrum-Oost  52.36424
# 2        Joan                  NaN             Centrum-West  52.37297
# 5       Edwin                  NaN             Centrum-West  52.36773
# 9     Tatiana                  NaN             Centrum-West  52.38071
# 10      Joost                  NaN  De Pijp - Rivierenbuurt  52.35247
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1     4.89396     Private room    236               1                340
# 2     4.88339  Entire home/apt    125              14                  5
# 5     4.89151     Private room     55               2                481
# 9     4.88610  Entire home/apt    115               7                177
# 10    4.90825  Entire home/apt    150               3                  3
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 1   2020-04-09               2.63                               2
# 2   2020-02-09               0.15                               1
# 5   2020-08-28               4.13                               2
# 9   2019-03-03               1.43                               5
# 10  2018-01-03               0.02                               1
#
#     availability_365
# 1                  0
# 2                 58
# 5                361
# 9                167
# 10                 0

# %%
dados.iloc[1:7]
# Out:
#       id                                               name  host_id  \
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  25428    Lovely apt in City Centre (w.lift) near Jordaan    56142
# 3  27886  Romantic, stylish B&B houseboat in canal district    97647
# 4  28871                            Comfortable double room   124245
# 5  29051                            Comfortable single room   124245
# 6  31080                2-story apartment + rooftop terrace   133488
#
#    host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 1  Alexander                  NaN  Centrum-Oost  52.36424    4.89396
# 2       Joan                  NaN  Centrum-West  52.37297    4.88339
# 3       Flip                  NaN  Centrum-West  52.38761    4.89188
# 4      Edwin                  NaN  Centrum-West  52.36719    4.89092
# 5      Edwin                  NaN  Centrum-West  52.36773    4.89151
# 6     Nienke                  NaN          Zuid  52.35132    4.84838
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 1     Private room    236               1                340  2020-04-09
# 2  Entire home/apt    125              14                  5  2020-02-09
# 3     Private room    138               2                219  2020-07-25
# 4     Private room     75               2                336  2020-09-20
# 5     Private room     55               2                481  2020-08-28
# 6  Entire home/apt    219               3                 32  2017-10-16
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 1               2.63                               2                 0
# 2               0.15                               1                58
# 3               2.05                               1               158
# 4               2.72                               2               340
# 5               4.13                               2               361
# 6               0.29                               1                 0

# %%
dados.iloc[lambda x: x.index % 10 == 0]
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 10        46386                     Cozy loft in central Amsterdam     207342
# 20        53692    Large quiet Studio with gardenview in hip area.     246493
# 30        64769                   Unique 3 bedroom house in Centre     312863
# 40        76459                  Yellow Studio Palamedes Amsterdam     400896
# ...         ...                                                ...        ...
# 18740  45629705                Charming 2BD Apartment Luxury Super  369645081
# 18750  45653371        Suite with bathroom in watervilla + parking    8325286
# 18760  45695711  Private Triple Room, Euphemia Hotel , city centre  367808546
# 18770  45737858  Spacious canalside en-suite double with character  234064710
# 18780  45777642                                Studio in Amsterdam   75268907
#
#            host_name  neighbourhood_group  \
# 0             Daniel                  NaN
# 10             Joost                  NaN
# 20              DoJo                  NaN
# 30         Marijntje                  NaN
# 40     Edwin + Karin                  NaN
# ...              ...                  ...
# 18740         Jeroen                  NaN
# 18750          Herve                  NaN
# 18760        Galanti                  NaN
# 18770       Virginia                  NaN
# 18780           Emma                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 0      Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 10                    De Pijp - Rivierenbuurt  52.35247    4.90825
# 20                    De Pijp - Rivierenbuurt  52.35348    4.90049
# 30                               Centrum-Oost  52.36225    4.90200
# 40                     De Baarsjes - Oud-West  52.36342    4.87558
# ...                                       ...       ...        ...
# 18740                            Centrum-Oost  52.36299    4.89367
# 18750                IJburg - Zeeburgereiland  52.36223    4.98286
# 18760                            Centrum-Oost  52.36162    4.89088
# 18770                            Centrum-West  52.36933    4.89350
# 18780                         Watergraafsmeer  52.34885    4.91878
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     59               3                278  2020-02-14
# 10     Entire home/apt    150               3                  3  2018-01-03
# 20        Private room     50               7                334  2020-08-20
# 30     Entire home/apt    450               4                 27  2019-01-05
# 40        Private room    115               4                 16  2017-09-06
# ...                ...    ...             ...                ...         ...
# 18740  Entire home/apt    147               3                  0         NaN
# 18750     Private room    200               1                  0         NaN
# 18760     Private room     69               1                  0         NaN
# 18770     Private room     68               3                  0         NaN
# 18780  Entire home/apt     33              10                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   1.98                               1                 0
# 10                  0.02                               1                 0
# 20                  2.93                               5                 0
# 30                  0.23                               1               251
# 40                  0.14                               2                 1
# ...                  ...                             ...               ...
# 18740                NaN                               1                11
# 18750                NaN                               1               364
# 18760                NaN                               5               265
# 18770                NaN                               1                94
# 18780                NaN                               1                15
#
# [1879 rows x 16 columns]

# %% [markdown]
# #### Loc

# %% [markdown]
# Com o método **.loc()** conseguimos, também, acessar índices através de inteiros, slices e booleanos. Porém, ao contrário do iloc, não conseguimos usar funções para acessar as linhas do DataFrame.

# %%
dados.loc[2:4]
# Out:
#       id                                               name  host_id  \
# 2  25428    Lovely apt in City Centre (w.lift) near Jordaan    56142
# 3  27886  Romantic, stylish B&B houseboat in canal district    97647
# 4  28871                            Comfortable double room   124245
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 2      Joan                  NaN  Centrum-West  52.37297    4.88339
# 3      Flip                  NaN  Centrum-West  52.38761    4.89188
# 4     Edwin                  NaN  Centrum-West  52.36719    4.89092
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 2  Entire home/apt    125              14                  5  2020-02-09
# 3     Private room    138               2                219  2020-07-25
# 4     Private room     75               2                336  2020-09-20
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 2               0.15                               1                58
# 3               2.05                               1               158
# 4               2.72                               2               340

# %% [markdown]
# É interessante pontuar que conseguimos acessar colunas através de *slices*, porém, ao invés de números usamos os nomes das colunas do *DataFrame*

# %%
slice_colunas = dados.loc[:,'id':'price']
slice_colunas
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1         20168       Studio with private bathroom in the centre 1      59484
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan      56142
# 3         27886  Romantic, stylish B&B houseboat in canal district      97647
# 4         28871                            Comfortable double room     124245
# ...         ...                                                ...        ...
# 18777  45761390              Charming 1Room Apartment in Amsterdam  310835509
# 18778  45763935         clean and light apartment nearby the water     961670
# 18779  45776325   A beautiful spacious room on a central location.   48168060
# 18780  45777642                                Studio in Amsterdam   75268907
# 18781  45783000             Spacious and cozy apartment in De Pijp  371160113
#
#         host_name  neighbourhood_group  \
# 0          Daniel                  NaN
# 1       Alexander                  NaN
# 2            Joan                  NaN
# 3            Flip                  NaN
# 4           Edwin                  NaN
# ...           ...                  ...
# 18777  TravelNest                  NaN
# 18778        Lisa                  NaN
# 18779         Tim                  NaN
# 18780        Emma                  NaN
# 18781     Nadezda                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 0      Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 1                                Centrum-Oost  52.36424    4.89396
# 2                                Centrum-West  52.37297    4.88339
# 3                                Centrum-West  52.38761    4.89188
# 4                                Centrum-West  52.36719    4.89092
# ...                                       ...       ...        ...
# 18777                           Bos en Lommer  52.37642    4.84941
# 18778                              Westerpark  52.39042    4.88204
# 18779                 De Pijp - Rivierenbuurt  52.34306    4.89995
# 18780                         Watergraafsmeer  52.34885    4.91878
# 18781                 De Pijp - Rivierenbuurt  52.35380    4.89740
#
#              room_type  price
# 0         Private room     59
# 1         Private room    236
# 2      Entire home/apt    125
# 3         Private room    138
# 4         Private room     75
# ...                ...    ...
# 18777  Entire home/apt    137
# 18778  Entire home/apt    120
# 18779     Private room     20
# 18780  Entire home/apt     33
# 18781  Entire home/apt    105
#
# [18782 rows x 10 columns]

# %% [markdown]
# ### Lição 8: Consultas dentro de DataFrames

# %% [markdown]
# Assim como fizemos consultas dentro de arrays, podemos fazer com *DataFrames* e *Series*.
#
# Essa consulta pode ser feita em todo *DataFrame* ou em apenas um conjunto de colunas.

# %% [markdown]
# Se quisermos saber, por exemplo, quais Airbnbs apresentam o número mínimo de noites maior que três podemos usar o seguinte código:

# %%
dados.minimum_nights > 3
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18777    False
# 18778     True
# 18779    False
# 18780     True
# 18781     True
# Name: minimum_nights, Length: 18782, dtype: bool

# %% [markdown]
# Esse código nos retorna uma *Series* preenchida com **True**, para os elementos que atendem a condição, ou **False**, para os que não atendem. Para melhorar o retorno desses dados, podemos fazer:

# %%
dados[dados.minimum_nights > 3]
# Out:
#              id                                             name    host_id  \
# 2         25428  Lovely apt in City Centre (w.lift) near Jordaan      56142
# 7         41125                Amsterdam Center Entire Apartment     178515
# 9         44129                    Luxury design with canal view     187728
# 14        50515       Family Home (No drugs, smoking or parties)     231864
# 18        53067      Spacious studio at the attic of a townhouse     246493
# ...         ...                                              ...        ...
# 18774  45746264      Studio at the Canals/Jordaan LONG TERM ONLY  367437974
# 18776  45752472      Affordable, Modern Twin Room Amsterdam city   15429464
# 18778  45763935       clean and light apartment nearby the water     961670
# 18780  45777642                              Studio in Amsterdam   75268907
# 18781  45783000           Spacious and cozy apartment in De Pijp  371160113
#
#       host_name  neighbourhood_group            neighbourhood  latitude  \
# 2          Joan                  NaN             Centrum-West  52.37297
# 7         Fatih                  NaN             Centrum-West  52.37891
# 9       Tatiana                  NaN             Centrum-West  52.38071
# 14        Karin                  NaN            Bos en Lommer  52.37632
# 18         DoJo                  NaN  De Pijp - Rivierenbuurt  52.35339
# ...         ...                  ...                      ...       ...
# 18774    Sophie                  NaN             Centrum-West  52.37438
# 18776      Iris                  NaN                     Zuid  52.35451
# 18778      Lisa                  NaN               Westerpark  52.39042
# 18780      Emma                  NaN          Watergraafsmeer  52.34885
# 18781   Nadezda                  NaN  De Pijp - Rivierenbuurt  52.35380
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 2        4.88339  Entire home/apt    125              14                  5
# 7        4.88321  Entire home/apt    160               4                 89
# 9        4.88610  Entire home/apt    115               7                177
# 14       4.83970  Entire home/apt    115               4                 17
# 18       4.90064     Private room     40               7                354
# ...          ...              ...    ...             ...                ...
# 18774    4.87751  Entire home/apt     90              21                  0
# 18776    4.87301     Private room     40              28                  0
# 18778    4.88204  Entire home/apt    120               5                  0
# 18780    4.91878  Entire home/apt     33              10                  0
# 18781    4.89740  Entire home/apt    105               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 2      2020-02-09               0.15                               1
# 7      2020-02-10               0.74                               1
# 9      2019-03-03               1.43                               5
# 14     2020-02-20               0.22                               1
# 18     2020-03-15               2.94                               5
# ...           ...                ...                             ...
# 18774         NaN                NaN                               1
# 18776         NaN                NaN                               2
# 18778         NaN                NaN                               2
# 18780         NaN                NaN                               1
# 18781         NaN                NaN                               1
#
#        availability_365
# 2                    58
# 7                     0
# 9                   167
# 14                    1
# 18                    0
# ...                 ...
# 18774                 0
# 18776                87
# 18778                51
# 18780                15
# 18781               253
#
# [3833 rows x 16 columns]

# %% [markdown]
# Dessa forma, ele retorna todas as informações dos hoteis com um mínimo de noites maior que 3.
#
# Além de permitir consultas desse tipo em uma única coluna, o **Pandas** permite consultarmos valores em múltiplas colunas ou em todo o *DataFrame*.
#
# Porém, para isso, os dados do *DataFrame* devem homogêneos (somente números ou somente textos, por exemplo)

# %%
colunas_numericas > 4
# Out:
#          id  host_id  neighbourhood_group  latitude  longitude  price  \
# 0      True     True                False      True       True   True
# 1      True     True                False      True       True   True
# 2      True     True                False      True       True   True
# 3      True     True                False      True       True   True
# 4      True     True                False      True       True   True
# ...     ...      ...                  ...       ...        ...    ...
# 18777  True     True                False      True       True   True
# 18778  True     True                False      True       True   True
# 18779  True     True                False      True       True   True
# 18780  True     True                False      True       True   True
# 18781  True     True                False      True       True   True
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0               False               True              False
# 1               False               True              False
# 2                True               True              False
# 3               False               True              False
# 4               False               True              False
# ...               ...                ...                ...
# 18777           False              False              False
# 18778            True              False              False
# 18779           False              False              False
# 18780            True              False              False
# 18781            True              False              False
#
#        calculated_host_listings_count  availability_365
# 0                               False             False
# 1                               False             False
# 2                               False              True
# 3                               False              True
# 4                               False              True
# ...                               ...               ...
# 18777                           False              True
# 18778                           False              True
# 18779                           False             False
# 18780                           False              True
# 18781                           False              True
#
# [18782 rows x 11 columns]

# %% [markdown]
# Podemos ver também que a consulta em *DataFrames* aceita **expressões relacionais**. Se estivéssemos buscando Airbnbs com mínimos de noites maiores que 3, apenas considerando os **Private room**, podemos fazer o seguinte:

# %%
dados[(dados.minimum_nights > 3) & (dados.room_type == 'Private room')]
# Out:
#              id                                               name    host_id  \
# 18        53067        Spacious studio at the attic of a townhouse     246493
# 20        53692    Large quiet Studio with gardenview in hip area.     246493
# 32        68290              Rebel - Private Room (only long term)     336950
# 39        75499                     Red Studio Palamedes Amsterdam     400896
# 40        76459                  Yellow Studio Palamedes Amsterdam     400896
# ...         ...                                                ...        ...
# 18636  45313147  Big room with view to the IJ river near the ce...    6037983
# 18642  45338272       Light and modern twin room in ideal location  366503180
# 18645  45346645            LUXURIOUS STAY IN AMSTERDAM CITY CENTRE   15429464
# 18678  45457698  Houseboat. Private quiet room in a great location  239030156
# 18776  45752472        Affordable, Modern Twin Room Amsterdam city   15429464
#
#            host_name  neighbourhood_group  \
# 18              DoJo                  NaN
# 20              DoJo                  NaN
# 32            Manuel                  NaN
# 39     Edwin + Karin                  NaN
# 40     Edwin + Karin                  NaN
# ...              ...                  ...
# 18636        Rodrigo                  NaN
# 18642          Hotel                  NaN
# 18645           Iris                  NaN
# 18678           Rene                  NaN
# 18776           Iris                  NaN
#
#                                 neighbourhood  latitude  longitude  \
# 18                    De Pijp - Rivierenbuurt  52.35339    4.90064
# 20                    De Pijp - Rivierenbuurt  52.35348    4.90049
# 32                               Centrum-West  52.36887    4.89523
# 39                     De Baarsjes - Oud-West  52.36145    4.87696
# 40                     De Baarsjes - Oud-West  52.36342    4.87558
# ...                                       ...       ...        ...
# 18636  Oostelijk Havengebied - Indische Buurt  52.37682    4.93528
# 18642                  De Baarsjes - Oud-West  52.36233    4.87651
# 18645                            Centrum-West  52.36628    4.89225
# 18678  Oostelijk Havengebied - Indische Buurt  52.36574    4.93522
# 18776                                    Zuid  52.35451    4.87301
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 18     Private room     40               7                354  2020-03-15
# 20     Private room     50               7                334  2020-08-20
# 32     Private room     45              30                659  2019-10-25
# 39     Private room    115               4                 33  2018-01-04
# 40     Private room    115               4                 16  2017-09-06
# ...             ...    ...             ...                ...         ...
# 18636  Private room     75               7                  0         NaN
# 18642  Private room     32              30                  0         NaN
# 18645  Private room     58              20                  0         NaN
# 18678  Private room    100               4                  0         NaN
# 18776  Private room     40              28                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 18                  2.94                               5                 0
# 20                  2.93                               5                 0
# 32                  5.65                               2               142
# 39                  0.30                               2               362
# 40                  0.14                               2                 1
# ...                  ...                             ...               ...
# 18636                NaN                               1                36
# 18642                NaN                               1                90
# 18645                NaN                               2                85
# 18678                NaN                               1                51
# 18776                NaN                               2                87
#
# [338 rows x 16 columns]

# %% [markdown]
# Além das consultas mostradas acima, os *DataFrames* oferecem o método **.query()**. Esse método faz a consulta dentro do *DataFrame* tendo como base uma expressão condicional passada como parâmetro.
#
# É interessante pontuar que esse tipo de acesso é muito aplicado em consultas **SQL** (Banco de dados).

# %%
dados.query('minimum_nights > 3')
# Out:
#              id                                             name    host_id  \
# 2         25428  Lovely apt in City Centre (w.lift) near Jordaan      56142
# 7         41125                Amsterdam Center Entire Apartment     178515
# 9         44129                    Luxury design with canal view     187728
# 14        50515       Family Home (No drugs, smoking or parties)     231864
# 18        53067      Spacious studio at the attic of a townhouse     246493
# ...         ...                                              ...        ...
# 18774  45746264      Studio at the Canals/Jordaan LONG TERM ONLY  367437974
# 18776  45752472      Affordable, Modern Twin Room Amsterdam city   15429464
# 18778  45763935       clean and light apartment nearby the water     961670
# 18780  45777642                              Studio in Amsterdam   75268907
# 18781  45783000           Spacious and cozy apartment in De Pijp  371160113
#
#       host_name  neighbourhood_group            neighbourhood  latitude  \
# 2          Joan                  NaN             Centrum-West  52.37297
# 7         Fatih                  NaN             Centrum-West  52.37891
# 9       Tatiana                  NaN             Centrum-West  52.38071
# 14        Karin                  NaN            Bos en Lommer  52.37632
# 18         DoJo                  NaN  De Pijp - Rivierenbuurt  52.35339
# ...         ...                  ...                      ...       ...
# 18774    Sophie                  NaN             Centrum-West  52.37438
# 18776      Iris                  NaN                     Zuid  52.35451
# 18778      Lisa                  NaN               Westerpark  52.39042
# 18780      Emma                  NaN          Watergraafsmeer  52.34885
# 18781   Nadezda                  NaN  De Pijp - Rivierenbuurt  52.35380
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 2        4.88339  Entire home/apt    125              14                  5
# 7        4.88321  Entire home/apt    160               4                 89
# 9        4.88610  Entire home/apt    115               7                177
# 14       4.83970  Entire home/apt    115               4                 17
# 18       4.90064     Private room     40               7                354
# ...          ...              ...    ...             ...                ...
# 18774    4.87751  Entire home/apt     90              21                  0
# 18776    4.87301     Private room     40              28                  0
# 18778    4.88204  Entire home/apt    120               5                  0
# 18780    4.91878  Entire home/apt     33              10                  0
# 18781    4.89740  Entire home/apt    105               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 2      2020-02-09               0.15                               1
# 7      2020-02-10               0.74                               1
# 9      2019-03-03               1.43                               5
# 14     2020-02-20               0.22                               1
# 18     2020-03-15               2.94                               5
# ...           ...                ...                             ...
# 18774         NaN                NaN                               1
# 18776         NaN                NaN                               2
# 18778         NaN                NaN                               2
# 18780         NaN                NaN                               1
# 18781         NaN                NaN                               1
#
#        availability_365
# 2                    58
# 7                     0
# 9                   167
# 14                    1
# 18                    0
# ...                 ...
# 18774                 0
# 18776                87
# 18778                51
# 18780                15
# 18781               253
#
# [3833 rows x 16 columns]

# %%
dados.query('minimum_nights > 3 & price < 100')
# Out:
#              id                                               name    host_id  \
# 18        53067        Spacious studio at the attic of a townhouse     246493
# 20        53692    Large quiet Studio with gardenview in hip area.     246493
# 32        68290              Rebel - Private Room (only long term)     336950
# 52       118097         all private, city center @ home with art-1     538659
# 66       171631  Pleasant,cosy & crazy apartment with small bal...     818479
# ...         ...                                                ...        ...
# 18677  45454506                              The Blake 3th floor C  178187873
# 18699  45513797          Centrally Located 1 Bdrm Apt in Amsterdam    1348274
# 18774  45746264        Studio at the Canals/Jordaan LONG TERM ONLY  367437974
# 18776  45752472        Affordable, Modern Twin Room Amsterdam city   15429464
# 18780  45777642                                Studio in Amsterdam   75268907
#
#                 host_name  neighbourhood_group            neighbourhood  \
# 18                   DoJo                  NaN  De Pijp - Rivierenbuurt
# 20                   DoJo                  NaN  De Pijp - Rivierenbuurt
# 32                 Manuel                  NaN             Centrum-West
# 52        Wendie And Hans                  NaN             Centrum-West
# 66                   Keja                  NaN   De Baarsjes - Oud-West
# ...                   ...                  ...                      ...
# 18677  Marcel And Pauline                  NaN             Centrum-Oost
# 18699                John                  NaN             Centrum-Oost
# 18774              Sophie                  NaN             Centrum-West
# 18776                Iris                  NaN                     Zuid
# 18780                Emma                  NaN          Watergraafsmeer
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 18     52.35339    4.90064     Private room     40               7
# 20     52.35348    4.90049     Private room     50               7
# 32     52.36887    4.89523     Private room     45              30
# 52     52.36571    4.88464     Private room     57               4
# 66     52.36339    4.85402  Entire home/apt     97               4
# ...         ...        ...              ...    ...             ...
# 18677  52.36490    4.88066  Entire home/apt     77               7
# 18699  52.36766    4.92563  Entire home/apt     65              14
# 18774  52.37438    4.87751  Entire home/apt     90              21
# 18776  52.35451    4.87301     Private room     40              28
# 18780  52.34885    4.91878  Entire home/apt     33              10
#
#        number_of_reviews last_review  reviews_per_month  \
# 18                   354  2020-03-15               2.94
# 20                   334  2020-08-20               2.93
# 32                   659  2019-10-25               5.65
# 52                   397  2020-10-09               3.82
# 66                    48  2019-09-17               0.43
# ...                  ...         ...                ...
# 18677                  0         NaN                NaN
# 18699                  0         NaN                NaN
# 18774                  0         NaN                NaN
# 18776                  0         NaN                NaN
# 18780                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 18                                  5                 0
# 20                                  5                 0
# 32                                  2               142
# 52                                  2                 0
# 66                                  1                 1
# ...                               ...               ...
# 18677                              20                29
# 18699                               3                 1
# 18774                               1                 0
# 18776                               2                87
# 18780                               1                15
#
# [953 rows x 16 columns]

# %% [markdown]
# O **.query()** também permite fazermos comparações com variáveis externas à expressão, veja:

# %%
minimo_noites = 100

dados.query('minimum_nights > @minimo_noites & price < 100')
# Out:
#             id                                             name    host_id  \
# 833    1536821               complete spacious studio in centre    8194617
# 3443   7332860                         Room in Amsterdam IJburg   11225917
# 8086  16376319  Spacious and clean apartment in Amsterdam North  107262947
#
#      host_name  neighbourhood_group             neighbourhood  latitude  \
# 833    Janneke                  NaN    De Baarsjes - Oud-West  52.37177
# 3443    Flávio                  NaN  IJburg - Zeeburgereiland  52.35437
# 8086   Wieneke                  NaN                Noord-Oost  52.40509
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 833     4.87212  Entire home/apt     70             180                120
# 3443    4.99750     Private room     45             180                333
# 8086    4.94335  Entire home/apt     55             181                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 833   2019-09-08               1.39                               1
# 3443  2019-07-31               5.22                               1
# 8086         NaN                NaN                               1
#
#       availability_365
# 833                164
# 3443               364
# 8086               363

# %%
dados.query('minimum_nights in [10,50,100,180]')
